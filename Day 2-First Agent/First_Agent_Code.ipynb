# %%
#  Step 1 — Install dependencies
# !pip install -q langchain langchain-community langchain-core python-dotenv openai

#  Step 2 — Imports
from langchain.agents import initialize_agent, AgentType, load_tools
from langchain_openai import ChatOpenAI
import os

# Step 3 — Set your OpenRouter API key directly
os.environ["OPENAI_API_KEY"] = "Add Your API Key Here"
os.environ["OPENAI_API_BASE"] = "https://openrouter.ai/api/v1"

# Step 4 — Initialize the model
llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.7)

# Step 5 — Load the math tool
tools = load_tools(["llm-math"], llm=llm)

# Step 6 — Create the agent
agent = initialize_agent(
    tools=tools,
    llm=llm,
    agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    verbose=True
)

#  Step 7 — Test it!
query = "What is 29% of 450?"
response = agent.run(query)
print("\n Final Answer:", response)
